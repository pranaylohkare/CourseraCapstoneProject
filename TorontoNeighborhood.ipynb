# %% [markdown]
# <h1> 1. Create Dataframe using the wikipedia link </h1>

# %%
from bs4 import BeautifulSoup # For Web scraping to get the table

import pandas as pd # library for data analsysis
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# <h3> First read the html page and create a dataframe </h3>

# %%
source_url = requests.get("https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M").text
soup = BeautifulSoup(source_url, 'xml')
table = soup.find('table',{'class':'wikitable sortable'})

# %%
# Loop through the table to build the DataFrame
table_rows = table.find_all('tr')
data = []
for row in table_rows:
    td=[]
    for t in row.find_all('td'):
        td.append(t.text.strip())
    data.append(td)
df = pd.DataFrame(data, columns=['PostalCode', 'Borough', 'Neighborhood'])

# %%
for tr_cell in table.find_all('tr'):
    row_data=[]
    for td_cell in tr_cell.find_all('td'):
        row_data.append(td_cell.text.strip())
    if len(row_data)==3:
        df.loc[len(df)] = row_data

# %%
df.head()
# Out:
#   PostalCode       Borough      Neighborhood
# 0       None          None              None
# 1        M1A  Not assigned      Not assigned
# 2        M2A  Not assigned      Not assigned
# 3        M3A    North York         Parkwoods
# 4        M4A    North York  Victoria Village

# %% [markdown]
# <h3> Data preprocessing and Cleaning -  </h3>

# %%
df = df[~df['Borough'].isnull()]  # to filter out bad rows
df.drop(df[df.Borough == 'Not assigned'].index, inplace=True) # Drop rows with a borough that is Not assigned.
df.reset_index(drop=True, inplace=True)
df = df.groupby(['PostalCode','Borough'])['Neighborhood'].apply(lambda x: ','.join(x)).reset_index()
df['Neighborhood'].replace('Not assigned',df['Borough'],inplace=True)
df
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# 30         M3K        North York
# 31         M3L        North York
# 32         M3M        North York
# 33         M3N        North York
# 34         M4A        North York
# 35         M4B         East York
# 36         M4C         East York
# 37         M4E      East Toronto
# 38         M4G         East York
# 39         M4H         East York
# 40         M4J         East York
# 41         M4K      East Toronto
# 42         M4L      East Toronto
# 43         M4M      East Toronto
# 44         M4N   Central Toronto
# 45         M4P   Central Toronto
# 46         M4R   Central Toronto
# 47         M4S   Central Toronto
# 48         M4T   Central Toronto
# 49         M4V   Central Toronto
# 50         M4W  Downtown Toronto
# 51         M4X  Downtown Toronto
# 52         M4Y  Downtown Toronto
# 53         M5A  Downtown Toronto
# 54         M5B  Downtown Toronto
# 55         M5C  Downtown Toronto
# 56         M5E  Downtown Toronto
# 57         M5G  Downtown Toronto
# 58         M5H  Downtown Toronto
# 59         M5J  Downtown Toronto
# 60         M5K  Downtown Toronto
# 61         M5L  Downtown Toronto
# 62         M5M        North York
# 63         M5N   Central Toronto
# 64         M5P   Central Toronto
# 65         M5R   Central Toronto
# 66         M5S  Downtown Toronto
# 67         M5T  Downtown Toronto
# 68         M5V  Downtown Toronto
# 69         M5W  Downtown Toronto
# 70         M5X  Downtown Toronto
# 71         M6A        North York
# 72         M6B        North York
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A  Downtown Toronto
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood
# 0                        Malvern, Rouge,Malvern, Rouge
# 1    Rouge Hill, Port Union, Highland Creek,Rouge H...
# 2    Guildwood, Morningside, West Hill,Guildwood, M...
# 3                                        Woburn,Woburn
# 4                                  Cedarbrae,Cedarbrae
# 5              Scarborough Village,Scarborough Village
# 6    Kennedy Park, Ionview, East Birchmount Park,Ke...
# 7    Golden Mile, Clairlea, Oakridge,Golden Mile, C...
# 8    Cliffside, Cliffcrest, Scarborough Village Wes...
# 9    Birch Cliff, Cliffside West,Birch Cliff, Cliff...
# 10   Dorset Park, Wexford Heights, Scarborough Town...
# 11                 Wexford, Maryvale,Wexford, Maryvale
# 12                                 Agincourt,Agincourt
# 13   Clarks Corners, Tam O'Shanter, Sullivan,Clarks...
# 14   Milliken, Agincourt North, Steeles East, L'Amo...
# 15   Steeles West, L'Amoreaux West,Steeles West, L'...
# 16                             Upper Rouge,Upper Rouge
# 17                 Hillcrest Village,Hillcrest Village
# 18   Fairview, Henry Farm, Oriole,Fairview, Henry F...
# 19                     Bayview Village,Bayview Village
# 20   York Mills, Silver Hills,York Mills, Silver Hills
# 21     Willowdale, Newtonbrook,Willowdale, Newtonbrook
# 22   Willowdale, Willowdale East,Willowdale, Willow...
# 23                     York Mills West,York Mills West
# 24   Willowdale, Willowdale West,Willowdale, Willow...
# 25                                 Parkwoods,Parkwoods
# 26                                 Don Mills,Don Mills
# 27                                 Don Mills,Don Mills
# 28   Bathurst Manor, Wilson Heights, Downsview Nort...
# 29   Northwood Park, York University,Northwood Park...
# 30                                 Downsview,Downsview
# 31                                 Downsview,Downsview
# 32                                 Downsview,Downsview
# 33                                 Downsview,Downsview
# 34                   Victoria Village,Victoria Village
# 35   Parkview Hill, Woodbine Gardens,Parkview Hill,...
# 36                   Woodbine Heights,Woodbine Heights
# 37                             The Beaches,The Beaches
# 38                                     Leaside,Leaside
# 39                   Thorncliffe Park,Thorncliffe Park
# 40   East Toronto, Broadview North (Old East York),...
# 41   The Danforth West, Riverdale,The Danforth West...
# 42   India Bazaar, The Beaches West,India Bazaar, T...
# 43                     Studio District,Studio District
# 44                         Lawrence Park,Lawrence Park
# 45                   Davisville North,Davisville North
# 46   North Toronto West,  Lawrence Park,North Toron...
# 47                               Davisville,Davisville
# 48   Moore Park, Summerhill East,Moore Park, Summer...
# 49   Summerhill West, Rathnelly, South Hill, Forest...
# 50                                   Rosedale,Rosedale
# 51   St. James Town, Cabbagetown,St. James Town, Ca...
# 52           Church and Wellesley,Church and Wellesley
# 53   Regent Park, Harbourfront,Regent Park, Harbour...
# 54   Garden District, Ryerson,Garden District, Ryerson
# 55                       St. James Town,St. James Town
# 56                             Berczy Park,Berczy Park
# 57               Central Bay Street,Central Bay Street
# 58   Richmond, Adelaide, King,Richmond, Adelaide, King
# 59   Harbourfront East, Union Station, Toronto Isla...
# 60   Toronto Dominion Centre, Design Exchange,Toron...
# 61   Commerce Court, Victoria Hotel,Commerce Court,...
# 62   Bedford Park, Lawrence Manor East,Bedford Park...
# 63                                   Roselawn,Roselawn
# 64   Forest Hill North & West, Forest Hill Road Par...
# 65   The Annex, North Midtown, Yorkville,The Annex,...
# 66   University of Toronto, Harbord,University of T...
# 67   Kensington Market, Chinatown, Grange Park,Kens...
# 68   CN Tower, King and Spadina, Railway Lands, Har...
# 69                       Stn A PO Boxes,Stn A PO Boxes
# 70   First Canadian Place, Underground city,First C...
# 71   Lawrence Manor, Lawrence Heights,Lawrence Mano...
# 72                                 Glencairn,Glencairn
# 73               Humewood-Cedarvale,Humewood-Cedarvale
# 74             Caledonia-Fairbanks,Caledonia-Fairbanks
# 75                                   Christie,Christie
# 76   Dufferin, Dovercourt Village,Dufferin, Doverco...
# 77   Little Portugal, Trinity,Little Portugal, Trinity
# 78   Brockton, Parkdale Village, Exhibition Place,B...
# 79   North Park, Maple Leaf Park, Upwood Park,North...
# 80   Del Ray, Mount Dennis, Keelsdale and Silvertho...
# 81   Runnymede, The Junction North,Runnymede, The J...
# 82   High Park, The Junction South,High Park, The J...
# 83       Parkdale, Roncesvalles,Parkdale, Roncesvalles
# 84               Runnymede, Swansea,Runnymede, Swansea
# 85   Queen's Park, Ontario Provincial Government,Qu...
# 86   Canada Post Gateway Processing Centre,Canada P...
# 87   Business reply mail Processing Centre, South C...
# 88   New Toronto, Mimico South, Humber Bay Shores,N...
# 89       Alderwood, Long Branch,Alderwood, Long Branch
# 90   The Kingsway, Montgomery Road, Old Mill North,...
# 91   Old Mill South, King's Mill Park, Sunnylea, Hu...
# 92   Mimico NW, The Queensway West, South of Bloor,...
# 93   Islington Avenue, Humber Valley Village,Isling...
# 94   West Deane Park, Princess Gardens, Martin Grov...
# 95   Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 96                         Humber Summit,Humber Summit
# 97                   Humberlea, Emery,Humberlea, Emery
# 98                                       Weston,Weston
# 99                                 Westmount,Westmount
# 100  Kingsview Village, St. Phillips, Martin Grove ...
# 101  South Steeles, Silverstone, Humbergate, Jamest...
# 102  Northwest, West Humber - Clairville,Northwest,...

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# <h3> Import csv file conatining the latitudes and longitudes of neighbourhoods in Canada </h3>

# %%
geo_coor = pd.read_csv('https://cocl.us/Geospatial_data')
geo_coor.head()
# Out:
#   Postal Code   Latitude  Longitude
# 0         M1B  43.806686 -79.194353
# 1         M1C  43.784535 -79.160497
# 2         M1E  43.763573 -79.188711
# 3         M1G  43.770992 -79.216917
# 4         M1H  43.773136 -79.239476

# %% [markdown]
# <h3> Merge the original DataFrame with the one with the coordinates </h3?

# %%
geo_coor.rename(columns={'Postal Code':'PostalCode'},inplace=True)
geo_coor.head()
df1 = pd.merge(df,geo_coor,on='PostalCode')
df1
# Out:
#     PostalCode           Borough  \
# 0          M1B       Scarborough
# 1          M1C       Scarborough
# 2          M1E       Scarborough
# 3          M1G       Scarborough
# 4          M1H       Scarborough
# 5          M1J       Scarborough
# 6          M1K       Scarborough
# 7          M1L       Scarborough
# 8          M1M       Scarborough
# 9          M1N       Scarborough
# 10         M1P       Scarborough
# 11         M1R       Scarborough
# 12         M1S       Scarborough
# 13         M1T       Scarborough
# 14         M1V       Scarborough
# 15         M1W       Scarborough
# 16         M1X       Scarborough
# 17         M2H        North York
# 18         M2J        North York
# 19         M2K        North York
# 20         M2L        North York
# 21         M2M        North York
# 22         M2N        North York
# 23         M2P        North York
# 24         M2R        North York
# 25         M3A        North York
# 26         M3B        North York
# 27         M3C        North York
# 28         M3H        North York
# 29         M3J        North York
# 30         M3K        North York
# 31         M3L        North York
# 32         M3M        North York
# 33         M3N        North York
# 34         M4A        North York
# 35         M4B         East York
# 36         M4C         East York
# 37         M4E      East Toronto
# 38         M4G         East York
# 39         M4H         East York
# 40         M4J         East York
# 41         M4K      East Toronto
# 42         M4L      East Toronto
# 43         M4M      East Toronto
# 44         M4N   Central Toronto
# 45         M4P   Central Toronto
# 46         M4R   Central Toronto
# 47         M4S   Central Toronto
# 48         M4T   Central Toronto
# 49         M4V   Central Toronto
# 50         M4W  Downtown Toronto
# 51         M4X  Downtown Toronto
# 52         M4Y  Downtown Toronto
# 53         M5A  Downtown Toronto
# 54         M5B  Downtown Toronto
# 55         M5C  Downtown Toronto
# 56         M5E  Downtown Toronto
# 57         M5G  Downtown Toronto
# 58         M5H  Downtown Toronto
# 59         M5J  Downtown Toronto
# 60         M5K  Downtown Toronto
# 61         M5L  Downtown Toronto
# 62         M5M        North York
# 63         M5N   Central Toronto
# 64         M5P   Central Toronto
# 65         M5R   Central Toronto
# 66         M5S  Downtown Toronto
# 67         M5T  Downtown Toronto
# 68         M5V  Downtown Toronto
# 69         M5W  Downtown Toronto
# 70         M5X  Downtown Toronto
# 71         M6A        North York
# 72         M6B        North York
# 73         M6C              York
# 74         M6E              York
# 75         M6G  Downtown Toronto
# 76         M6H      West Toronto
# 77         M6J      West Toronto
# 78         M6K      West Toronto
# 79         M6L        North York
# 80         M6M              York
# 81         M6N              York
# 82         M6P      West Toronto
# 83         M6R      West Toronto
# 84         M6S      West Toronto
# 85         M7A  Downtown Toronto
# 86         M7R       Mississauga
# 87         M7Y      East Toronto
# 88         M8V         Etobicoke
# 89         M8W         Etobicoke
# 90         M8X         Etobicoke
# 91         M8Y         Etobicoke
# 92         M8Z         Etobicoke
# 93         M9A         Etobicoke
# 94         M9B         Etobicoke
# 95         M9C         Etobicoke
# 96         M9L        North York
# 97         M9M        North York
# 98         M9N              York
# 99         M9P         Etobicoke
# 100        M9R         Etobicoke
# 101        M9V         Etobicoke
# 102        M9W         Etobicoke
#
#                                           Neighborhood   Latitude  Longitude
# 0                        Malvern, Rouge,Malvern, Rouge  43.806686 -79.194353
# 1    Rouge Hill, Port Union, Highland Creek,Rouge H...  43.784535 -79.160497
# 2    Guildwood, Morningside, West Hill,Guildwood, M...  43.763573 -79.188711
# 3                                        Woburn,Woburn  43.770992 -79.216917
# 4                                  Cedarbrae,Cedarbrae  43.773136 -79.239476
# 5              Scarborough Village,Scarborough Village  43.744734 -79.239476
# 6    Kennedy Park, Ionview, East Birchmount Park,Ke...  43.727929 -79.262029
# 7    Golden Mile, Clairlea, Oakridge,Golden Mile, C...  43.711112 -79.284577
# 8    Cliffside, Cliffcrest, Scarborough Village Wes...  43.716316 -79.239476
# 9    Birch Cliff, Cliffside West,Birch Cliff, Cliff...  43.692657 -79.264848
# 10   Dorset Park, Wexford Heights, Scarborough Town...  43.757410 -79.273304
# 11                 Wexford, Maryvale,Wexford, Maryvale  43.750072 -79.295849
# 12                                 Agincourt,Agincourt  43.794200 -79.262029
# 13   Clarks Corners, Tam O'Shanter, Sullivan,Clarks...  43.781638 -79.304302
# 14   Milliken, Agincourt North, Steeles East, L'Amo...  43.815252 -79.284577
# 15   Steeles West, L'Amoreaux West,Steeles West, L'...  43.799525 -79.318389
# 16                             Upper Rouge,Upper Rouge  43.836125 -79.205636
# 17                 Hillcrest Village,Hillcrest Village  43.803762 -79.363452
# 18   Fairview, Henry Farm, Oriole,Fairview, Henry F...  43.778517 -79.346556
# 19                     Bayview Village,Bayview Village  43.786947 -79.385975
# 20   York Mills, Silver Hills,York Mills, Silver Hills  43.757490 -79.374714
# 21     Willowdale, Newtonbrook,Willowdale, Newtonbrook  43.789053 -79.408493
# 22   Willowdale, Willowdale East,Willowdale, Willow...  43.770120 -79.408493
# 23                     York Mills West,York Mills West  43.752758 -79.400049
# 24   Willowdale, Willowdale West,Willowdale, Willow...  43.782736 -79.442259
# 25                                 Parkwoods,Parkwoods  43.753259 -79.329656
# 26                                 Don Mills,Don Mills  43.745906 -79.352188
# 27                                 Don Mills,Don Mills  43.725900 -79.340923
# 28   Bathurst Manor, Wilson Heights, Downsview Nort...  43.754328 -79.442259
# 29   Northwood Park, York University,Northwood Park...  43.767980 -79.487262
# 30                                 Downsview,Downsview  43.737473 -79.464763
# 31                                 Downsview,Downsview  43.739015 -79.506944
# 32                                 Downsview,Downsview  43.728496 -79.495697
# 33                                 Downsview,Downsview  43.761631 -79.520999
# 34                   Victoria Village,Victoria Village  43.725882 -79.315572
# 35   Parkview Hill, Woodbine Gardens,Parkview Hill,...  43.706397 -79.309937
# 36                   Woodbine Heights,Woodbine Heights  43.695344 -79.318389
# 37                             The Beaches,The Beaches  43.676357 -79.293031
# 38                                     Leaside,Leaside  43.709060 -79.363452
# 39                   Thorncliffe Park,Thorncliffe Park  43.705369 -79.349372
# 40   East Toronto, Broadview North (Old East York),...  43.685347 -79.338106
# 41   The Danforth West, Riverdale,The Danforth West...  43.679557 -79.352188
# 42   India Bazaar, The Beaches West,India Bazaar, T...  43.668999 -79.315572
# 43                     Studio District,Studio District  43.659526 -79.340923
# 44                         Lawrence Park,Lawrence Park  43.728020 -79.388790
# 45                   Davisville North,Davisville North  43.712751 -79.390197
# 46   North Toronto West,  Lawrence Park,North Toron...  43.715383 -79.405678
# 47                               Davisville,Davisville  43.704324 -79.388790
# 48   Moore Park, Summerhill East,Moore Park, Summer...  43.689574 -79.383160
# 49   Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 50                                   Rosedale,Rosedale  43.679563 -79.377529
# 51   St. James Town, Cabbagetown,St. James Town, Ca...  43.667967 -79.367675
# 52           Church and Wellesley,Church and Wellesley  43.665860 -79.383160
# 53   Regent Park, Harbourfront,Regent Park, Harbour...  43.654260 -79.360636
# 54   Garden District, Ryerson,Garden District, Ryerson  43.657162 -79.378937
# 55                       St. James Town,St. James Town  43.651494 -79.375418
# 56                             Berczy Park,Berczy Park  43.644771 -79.373306
# 57               Central Bay Street,Central Bay Street  43.657952 -79.387383
# 58   Richmond, Adelaide, King,Richmond, Adelaide, King  43.650571 -79.384568
# 59   Harbourfront East, Union Station, Toronto Isla...  43.640816 -79.381752
# 60   Toronto Dominion Centre, Design Exchange,Toron...  43.647177 -79.381576
# 61   Commerce Court, Victoria Hotel,Commerce Court,...  43.648198 -79.379817
# 62   Bedford Park, Lawrence Manor East,Bedford Park...  43.733283 -79.419750
# 63                                   Roselawn,Roselawn  43.711695 -79.416936
# 64   Forest Hill North & West, Forest Hill Road Par...  43.696948 -79.411307
# 65   The Annex, North Midtown, Yorkville,The Annex,...  43.672710 -79.405678
# 66   University of Toronto, Harbord,University of T...  43.662696 -79.400049
# 67   Kensington Market, Chinatown, Grange Park,Kens...  43.653206 -79.400049
# 68   CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 69                       Stn A PO Boxes,Stn A PO Boxes  43.646435 -79.374846
# 70   First Canadian Place, Underground city,First C...  43.648429 -79.382280
# 71   Lawrence Manor, Lawrence Heights,Lawrence Mano...  43.718518 -79.464763
# 72                                 Glencairn,Glencairn  43.709577 -79.445073
# 73               Humewood-Cedarvale,Humewood-Cedarvale  43.693781 -79.428191
# 74             Caledonia-Fairbanks,Caledonia-Fairbanks  43.689026 -79.453512
# 75                                   Christie,Christie  43.669542 -79.422564
# 76   Dufferin, Dovercourt Village,Dufferin, Doverco...  43.669005 -79.442259
# 77   Little Portugal, Trinity,Little Portugal, Trinity  43.647927 -79.419750
# 78   Brockton, Parkdale Village, Exhibition Place,B...  43.636847 -79.428191
# 79   North Park, Maple Leaf Park, Upwood Park,North...  43.713756 -79.490074
# 80   Del Ray, Mount Dennis, Keelsdale and Silvertho...  43.691116 -79.476013
# 81   Runnymede, The Junction North,Runnymede, The J...  43.673185 -79.487262
# 82   High Park, The Junction South,High Park, The J...  43.661608 -79.464763
# 83       Parkdale, Roncesvalles,Parkdale, Roncesvalles  43.648960 -79.456325
# 84               Runnymede, Swansea,Runnymede, Swansea  43.651571 -79.484450
# 85   Queen's Park, Ontario Provincial Government,Qu...  43.662301 -79.389494
# 86   Canada Post Gateway Processing Centre,Canada P...  43.636966 -79.615819
# 87   Business reply mail Processing Centre, South C...  43.662744 -79.321558
# 88   New Toronto, Mimico South, Humber Bay Shores,N...  43.605647 -79.501321
# 89       Alderwood, Long Branch,Alderwood, Long Branch  43.602414 -79.543484
# 90   The Kingsway, Montgomery Road, Old Mill North,...  43.653654 -79.506944
# 91   Old Mill South, King's Mill Park, Sunnylea, Hu...  43.636258 -79.498509
# 92   Mimico NW, The Queensway West, South of Bloor,...  43.628841 -79.520999
# 93   Islington Avenue, Humber Valley Village,Isling...  43.667856 -79.532242
# 94   West Deane Park, Princess Gardens, Martin Grov...  43.650943 -79.554724
# 95   Eringate, Bloordale Gardens, Old Burnhamthorpe...  43.643515 -79.577201
# 96                         Humber Summit,Humber Summit  43.756303 -79.565963
# 97                   Humberlea, Emery,Humberlea, Emery  43.724766 -79.532242
# 98                                       Weston,Weston  43.706876 -79.518188
# 99                                 Westmount,Westmount  43.696319 -79.532242
# 100  Kingsview Village, St. Phillips, Martin Grove ...  43.688905 -79.554724
# 101  South Steeles, Silverstone, Humbergate, Jamest...  43.739416 -79.588437
# 102  Northwest, West Humber - Clairville,Northwest,...  43.706748 -79.594054

# %% [markdown]
# <h1> Exploring and clustering the neighborhoods in Toronto</h1>

# %% [markdown]
# <h3>Getting all the neighborhoods that contain 'Toronto' in them</h3>

# %%
df2 = df1[df1['Borough'].str.contains('Toronto',regex=False)]
df2
# Out:
#    PostalCode           Borough  \
# 37        M4E      East Toronto
# 41        M4K      East Toronto
# 42        M4L      East Toronto
# 43        M4M      East Toronto
# 44        M4N   Central Toronto
# 45        M4P   Central Toronto
# 46        M4R   Central Toronto
# 47        M4S   Central Toronto
# 48        M4T   Central Toronto
# 49        M4V   Central Toronto
# 50        M4W  Downtown Toronto
# 51        M4X  Downtown Toronto
# 52        M4Y  Downtown Toronto
# 53        M5A  Downtown Toronto
# 54        M5B  Downtown Toronto
# 55        M5C  Downtown Toronto
# 56        M5E  Downtown Toronto
# 57        M5G  Downtown Toronto
# 58        M5H  Downtown Toronto
# 59        M5J  Downtown Toronto
# 60        M5K  Downtown Toronto
# 61        M5L  Downtown Toronto
# 63        M5N   Central Toronto
# 64        M5P   Central Toronto
# 65        M5R   Central Toronto
# 66        M5S  Downtown Toronto
# 67        M5T  Downtown Toronto
# 68        M5V  Downtown Toronto
# 69        M5W  Downtown Toronto
# 70        M5X  Downtown Toronto
# 75        M6G  Downtown Toronto
# 76        M6H      West Toronto
# 77        M6J      West Toronto
# 78        M6K      West Toronto
# 82        M6P      West Toronto
# 83        M6R      West Toronto
# 84        M6S      West Toronto
# 85        M7A  Downtown Toronto
# 87        M7Y      East Toronto
#
#                                          Neighborhood   Latitude  Longitude
# 37                            The Beaches,The Beaches  43.676357 -79.293031
# 41  The Danforth West, Riverdale,The Danforth West...  43.679557 -79.352188
# 42  India Bazaar, The Beaches West,India Bazaar, T...  43.668999 -79.315572
# 43                    Studio District,Studio District  43.659526 -79.340923
# 44                        Lawrence Park,Lawrence Park  43.728020 -79.388790
# 45                  Davisville North,Davisville North  43.712751 -79.390197
# 46  North Toronto West,  Lawrence Park,North Toron...  43.715383 -79.405678
# 47                              Davisville,Davisville  43.704324 -79.388790
# 48  Moore Park, Summerhill East,Moore Park, Summer...  43.689574 -79.383160
# 49  Summerhill West, Rathnelly, South Hill, Forest...  43.686412 -79.400049
# 50                                  Rosedale,Rosedale  43.679563 -79.377529
# 51  St. James Town, Cabbagetown,St. James Town, Ca...  43.667967 -79.367675
# 52          Church and Wellesley,Church and Wellesley  43.665860 -79.383160
# 53  Regent Park, Harbourfront,Regent Park, Harbour...  43.654260 -79.360636
# 54  Garden District, Ryerson,Garden District, Ryerson  43.657162 -79.378937
# 55                      St. James Town,St. James Town  43.651494 -79.375418
# 56                            Berczy Park,Berczy Park  43.644771 -79.373306
# 57              Central Bay Street,Central Bay Street  43.657952 -79.387383
# 58  Richmond, Adelaide, King,Richmond, Adelaide, King  43.650571 -79.384568
# 59  Harbourfront East, Union Station, Toronto Isla...  43.640816 -79.381752
# 60  Toronto Dominion Centre, Design Exchange,Toron...  43.647177 -79.381576
# 61  Commerce Court, Victoria Hotel,Commerce Court,...  43.648198 -79.379817
# 63                                  Roselawn,Roselawn  43.711695 -79.416936
# 64  Forest Hill North & West, Forest Hill Road Par...  43.696948 -79.411307
# 65  The Annex, North Midtown, Yorkville,The Annex,...  43.672710 -79.405678
# 66  University of Toronto, Harbord,University of T...  43.662696 -79.400049
# 67  Kensington Market, Chinatown, Grange Park,Kens...  43.653206 -79.400049
# 68  CN Tower, King and Spadina, Railway Lands, Har...  43.628947 -79.394420
# 69                      Stn A PO Boxes,Stn A PO Boxes  43.646435 -79.374846
# 70  First Canadian Place, Underground city,First C...  43.648429 -79.382280
# 75                                  Christie,Christie  43.669542 -79.422564
# 76  Dufferin, Dovercourt Village,Dufferin, Doverco...  43.669005 -79.442259
# 77  Little Portugal, Trinity,Little Portugal, Trinity  43.647927 -79.419750
# 78  Brockton, Parkdale Village, Exhibition Place,B...  43.636847 -79.428191
# 82  High Park, The Junction South,High Park, The J...  43.661608 -79.464763
# 83      Parkdale, Roncesvalles,Parkdale, Roncesvalles  43.648960 -79.456325
# 84              Runnymede, Swansea,Runnymede, Swansea  43.651571 -79.484450
# 85  Queen's Park, Ontario Provincial Government,Qu...  43.662301 -79.389494
# 87  Business reply mail Processing Centre, South C...  43.662744 -79.321558

# %% [markdown]
# <h3> Map visualization using Folium </h3>

# %%
map_toronto = folium.Map(location=[43.651070,-79.347015],zoom_start=11)

for lat,lng,borough,neighborhood in zip(df2['Latitude'],df2['Longitude'],df2['Borough'],df2['Neighborhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
    [lat,lng],
    radius=5,
    popup=label,
    color='blue',
    fill=True,
    fill_color='#3186cc',
    fill_opacity=0.7,
    parse_html=False).add_to(map_toronto)
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h1> Cluster Neighborhoods </h1>

# %% [markdown]
# <h3> Using K-Means Clustering </h3>

# %%
k=5
toronto_clustering = df2.drop(['PostalCode','Borough','Neighborhood'],1)
kmeans = KMeans(n_clusters = k,random_state=0).fit(toronto_clustering)
kmeans.labels_
df2.insert(0, 'ClusterLabels', kmeans.labels_)

# %%
# create map
map_clusters = folium.Map(location=[43.651070,-79.347015],zoom_start=11)

# set color scheme for the clusters
x = np.arange(k)
ys = [i + x + (i*x)**2 for i in range(k)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, neighborhood, cluster in zip(df2['Latitude'], df2['Longitude'], df2['Neighborhood'], df2['ClusterLabels']):
    label = folium.Popup(' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# <h3> To view the maps please use the links below </h3>
#
# <a href="https://github.com/pranaylohkare/Coursera_Capstone/blob/master/Screen%20Shot%202020-07-06%20at%205.35.19%20PM.png">Map1</a>
# <a href="https://github.com/pranaylohkare/Coursera_Capstone/blob/master/Screen%20Shot%202020-07-06%20at%205.34.40%20PM.png">Map2</a>
